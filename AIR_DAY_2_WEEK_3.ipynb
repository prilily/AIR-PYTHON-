# %% [markdown]
# # **`AGENDA`**

# %% [markdown]
# **`PYTHON FUNCTIONS`**
# 1. `Functions in Python`
# 2. `Functions vs Methods`
# 3. `Parameters vs Arguments`
# 4. `How To Define a Function: User-Defined Functions (UDFs)`
# 5. `The returnstatement`
# 6. `How To Call a Function`
# 7. `How To Add Docstrings to a Python Function`
# 8. `Function Arguments in Python`
# 9. `Global vs Local Variables`
# 10. `Anonymous Functions in Python`
# 11. `Using main() as a Function`

# %% [markdown]
# # `PYTHON FUNCTIONS`
# `The what,why, how, when and where`

# %%
#take input from user and print table upto that number
x=5

1*1=1
1*2=2
...........1*10=10

2*1=2
2*2=4
...........2*10=20

3*1=3
3*2=6
...........3*10=30

4*1=4
4*2=8
...........4*10=40

5*1=5
5*2=10
...........5*10=50

# %% [markdown]
# **`WHAT`**
#
# `You use functions in programming to bundle a set of instructions that you want to use repeatedly`
#
# `NOUN: an activity that is natural to or the purpose of a person or thing.`
#
# `VERB: work or operate in a proper or particular way.`
#
#
# ```
# MATHS: a relation or expression involving one or more variables.
#         or a relation from a set of inputs to a set of possible outputs where
#         each input is related to exactly one output.
#         f(x)=x^2   or
#         y=f(x) ,y:output, x:input, f(x) any transformation( + - / *)
#         so,
#         y=2x+1
#         we return it as y
# ```
#
#
# ```
# A function is a block of organized, reusable code that is used to perform a single, related action.
#
# It does the same thing every time.
# For every input, you can get only one output
#
# ```

# %% [markdown]
# **`WHY`**
#
# ` Functions allow us to teach the computer how to do something one time and easily reuse the code to do it again later.`
#
# ` Remember, Don’t Repeat Yourself!`
#
# `A way to organise our code, make our code more readable, and remove repeated blocks of code`
#
# `With the help of functions, we can `**`avoid rewriting the same logic`**` or code again and again in a program.`
#
# `In a single Program, we can call Python functions anywhere and also `**`call multiple times.`**
#
# `We can track a large Python program easily when it is divided into multiple functions.`
#
# `The main achievement of Python functions is its `**`Reusability.`**

# %% [markdown]
# **`WHEN`**
# ```
# Suppose you are writing code to build an application.
# In your development journey, you want to reuse the code of a few lines (100) at different places.
# For your Application, functions are helpful. We can write functions at one
# place and we will be able to access those functions from anywhere in the program.
# ```
# `eg: BUILDING A CALCULATOR`

# %% [markdown]
# **`HOW`**
# ```
# def function_name(parameters):
# 	"""docstring"""
# 	statement(s)
#   ```
# - **`Keyword`** `def that marks the start of the function header`.
# - A **`function name`** `to uniquely identify the function. Function naming follows the same rules of writing identifiers in Python.`
# - **`Parameters`** `(arguments) through which we pass values to a function. They are optional.`
# - A **`colon (:)`** `to mark the end of the function header.`
# - `Optional` **`documentation`** `string (docstring) to describe what the function does.`
# - `One or more valid` **`python statements`**` that make up the function body`
# - `Statements must have the` **`same indentation level`** (usually 4 spaces).
# - `An optional `**`return statement`** `to return a value from the function.`

# %%
def greeting_week3():
  print("Hello, welcome to learning function")

greeting_week3()
greeting_week3=7
print(greeting_week3)
# Out:
# Hello, welcome to learning function
# 7

# %%
def greet(name):
    """
    This function greets to
    the person passed in as
    a parameter
    """
    print("Hello, " + name + ". Good morning!")

# %%
greet('Shivani')

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **`User-defined functions – These functions are defined by the user to perform a specific task.`**
#
# **`Built-in functions – These functions are pre-defined functions in Python.`**
# ```
# print() to print an object to the terminal
# ```
#
# **`Anonymous functions, which are also called lambda functions because they are not declared with the standard def keyword.`**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def greeting():
  print("Greetings")
  return

greeting()
# Out:
# Greetings

# %%
def greeting_1():
  print("Greetings")
  return "Hello"

x=greeting()
print(x)
# Out:
# Greetings
# None

# %% [markdown]
# # `Functions vs Methods`

# %% [markdown]
# `A method refers to a function which is part of a class. You access it with an instance or object of the class.`
#
# `A function doesn’t have this restriction: it just refers to a standalone function.`
#
# **` This means that all methods are functions, but not all functions are methods`**

# %%
# Define a function `plus()`
def plus(a,b):
  return a + b
  
# Create a `Summation` class
class Summation(object):
  def sum(self, a, b):
    self.contents = a + b
    return self.contents

# %%
sumInstance = Summation()
sumInstance.sum(1,2)
# Out:
# 3

# %%
plus(2,3)
# Out:
# 5

# %% [markdown]
# # `Parameters vs Arguments`

# %% [markdown]
# **`Parameters`**` are the names used when defining a function or a method, and into which arguments will be mapped. `
#
# **`Arguments`**` are the things which are supplied to any function or method call, while the function or method code refers to the arguments by their parameter names.`

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # `How To Define a Function: User-Defined Functions (UDFs)`

# %% [markdown]
# Writing Function Step-wise
#
#
# - Use the keyword **def** to declare the function and follow this up with the **function name**.
# -Add **parameters** to the function: they should be within the parentheses of the function.
# -End your line with a **colon.**
# -Add **statements** that the functions should execute.
# -End your function with a **return statement** if the function should output something.
#    - Without the return statement,
# your function will return an object None.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ```
# def function_name(parameters):
# 	"""docstring"""
# 	statement(s)
#   ```
# - **`Keyword`** `def that marks the start of the function header`.
# - A **`function name`** `to uniquely identify the function. Function naming follows the same rules of writing identifiers in Python.`
# - **`Parameters`** `(arguments) through which we pass values to a function. They are optional.`
# - A **`colon (:)`** `to mark the end of the function header.`
# - `Optional` **`documentation`** `string (docstring) to describe what the function does.`
# - `One or more valid` **`python statements`**` that make up the function body`
# - `Statements must have the` **`same indentation level`** (usually 4 spaces).
# - `An optional `**`return statement`** `to return a value from the function.`

# %%
# No parameters no return Type
def hello_2():
  print("Hello from function 1") 
  return 

hello_2()
# Out:
# Hello from function 1

# %%
#adding flow control
def hello():
  hello_2()
  name = str(input("Enter your name: "))
  if name:
    print ("Hello " + str(name))
  else:
    print("Hello World") 
  return 
  
hello()
# Out:
# Hello from function 1
# Enter your name: priyanka
# Hello priyanka

# %% [markdown]
# # `The return statement`

# %% [markdown]
# ```
# If you want to continue to work with the result of your function and
# try out some operations on it, you will need to use the
# return statement
# to actually return a value, such as a String, an integer,
# ```
#
#
# **`Functions immediately exit when they come across a return statement, even if it means that they won’t return any value`**

# %%
def hello():
  print("Hello World") 
  return("hello ")

def hello_noreturn():
  print("Hello World")

# %%
# Multiply the output of `hello()` with 2 
hello() * 2

#we get an error : TypeError that says that you can’t do the multiplication operation for NoneType

# %%
# (Try to) multiply the output of `hello_noreturn()` with 2 
hello_noreturn() * 2

# %%
#eg for return
def run():
  for x in range(10):
    print(x)
    if(x ==5):
       return
  print("Run!")
  
run()

# %% [markdown]
# ` In the return statement you can use it to return multiple values.`
#
# **`using tuples`**
#
# Note: Remember Tuples are immutable : ` which means that you can’t modify any amounts that are stored in it!`
#
# `You can unpack tuples into multiple variables with the help of the comma and the assignment operator.`

# %%
# Define `plus()`
def plus(a,b):
  sum = a + b
  return (sum, b)

# Call `plus()` and unpack variables

sum, a = plus(3,4)

# Print `sum()`
print(sum)
print(a)
# Out:
# 7
# 4

# %% [markdown]
# # `How To Call a Function`

# %% [markdown]
# `Calling a function means that you execute the function that you have defined - either directly from the Python prompt or through another function`

# %%
def greet(name):
    """
    This function greets to
    the person passed in as
    a parameter
    """
    print("Hello, " + name + ". Good morning!")


greet("Daniel")
# Out:
# Hello, Daniel. Good morning!

# %%
#calling with no parameters
greet()

# %%
#passing diff datatypes
greet(5)

# %% [markdown]
# # `How To Add Docstrings to a Python Function`

# %% [markdown]
# `Function docstrings are placed in the immediate line after the function header and are placed in between triple quotation marks. ’.`

# %%
def hello():
  """Prints "Hello World".

  Returns:
    None
  """ 
  print("Hello World") 
  return

# %% [markdown]
# # `Function Arguments in Python`

# %% [markdown]
# ```
# Arguments are the things which are given to any function or method call,
#
# while the function or method code refers to the arguments by their parameter names.
# There are four types of arguments that Python UDFs can take:
# ```
#
# 1. Default arguments
# 2. Required arguments
# 3. Keyword arguments
# 4. Variable number of arguments
#
# **`Default Arguments`**
# ```
# Default arguments are those that take a default value if no argument value is passed during the function call.
# You can assign this default value by with the assignment operator
# eg:
# def plus(a,b = 2):
#   return a + b
# ```

# %%
# Define `plus()` function
def plus(a,b = 2):
  return a + b
  
# Call `plus()` with only `a` parameter
plus(a=1)

#

# %%
plus(a=1, b=3)

# %% [markdown]
# **`Required Arguments`**
# ```
# These arguments need to be passed during the function call and in precisely the right order
# eg:
# The result will vary if the order is changed
# def plus(a,b):
#   return a / b
#
# ```

# %%
def divide(a,b):
  return a / b

# %%
divide(20,10)
# Out:
# 2.0

# %%
divide(b=20,a=10)
# Out:
# 0.5

# %% [markdown]
# **`Keyword Arguments`**
#
#
# ```
# If you want to make sure that you call all the parameters in the right order,
# you can use the keyword arguments in your function call.
# You use these to identify the arguments by their parameter name.
# eg:
# def plus(a,b):
#   return a + b
#
# plus(a=5,b=10)
# ```
# **`Note that by using the keyword arguments, you can also switch around the order of the parameters and still get the same result when you execute your function:`**
# `plus(b=10,a=12)

# %%
# Define `plus()` function
def plus(a,b):
  return a + b
  
# Call `plus()` function with keyword arguments
plus(b=2, a=1)
# Out:
# 3

# %%
plus(a=5,b=10)

# %% [markdown]
# **`Variable number of Arguments`**
# ```
# In cases where you don’t know the exact number of arguments
# that you want to pass to a function, you can use the following syntax with *args:
# eg:
# def plus(*args):
#   return sum(args)
#
# # Calculate the sum
# plus(1,4,5)
#
# sum is inbuilt
#
#
# The asterisk (*) is placed before the variable name that holds the values of all nonkeyword variable arguments.
#
# Note here that you might as well have passed *varint, *var_int_args or any other name to the plus() function.
# ```

# %%
# Define `plus()` function to accept a variable number of arguments
def plus(*args):
  total = 0
  for i in args:
    total += i
  return total

# Calculate the sum  
plus(20,30,40,50)
# Out:
# 140

# %%
plus(20,20)
# Out:
# 40

# %% [markdown]
# # `Global vs Local Variables`

# %% [markdown]
# **`SCOPE OF A VARIABLE`**
#
# `Scope of a variable is the `**portion of a program where the variable is recognized.**
#
# ` Parameters and variables defined inside a function are not visible from outside the function. Hence, they have a `**`local scope.`**
#
# `variables outside of the function are visible from inside. They have a `**`global scope.`**
#
# We can **`read these values from inside the function but cannot change (write) them.`**
#
# `In order to modify the value of variables outside the function, they must be declared as global variables using the` **keyword global.**

# %%
def my_func():
	x = 10
	print("Value inside function:",x)

x = 20
my_func()
print("Value outside function:",x)
# Out:
# Value inside function: 10
# Value outside function: 20

# %% [markdown]
# ```
# The lifetime of a variable is the period throughout which the variable exits in the memory.
# The lifetime of variables inside a function is as long as the function executes.
# ```
#
# `They are destroyed once we return from the function. Hence, a function does not remember the value of a variable from its previous calls.`

# %%
# Global variable `init`
init = 1

# Define `plus()` function to accept a variable number of arguments
def plus(*args):
  # Local variable `sum()`
  total = 0
  for i in args:
    total += i
  return total

# %%
# Access the global variable
print("this is the initialized value " + str(init))
# Out:
# this is the initialized value 1

# %%
# (Try to) access the local variable
print("this is the sum " + str(total))


#get NameError
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-84-399e41282d39> in <module>()
#       1 # (Try to) access the local variable
# ----> 2 print("this is the sum " + str(total))
#       3
#       4
#       5 #get NameError
#
# NameError: name 'total' is not defined

# %% [markdown]
# # `Anonymous Functions in Python`

# %% [markdown]
# ```
# Anonymous functions are also called lambda functions in Python because instead of declaring them with the standard def keyword,
# you use the lambda keyword.
# ```

# %% [markdown]
# ```
# You use anonymous functions when you require a nameless function for a short period of time, and that is created at runtime
# ```

# %%
double = lambda x: x*2

double(20)
# Out:
# 40

# %% [markdown]
# ```
# What’s special about this function is that it has no name,
# like the examples that you have seen in the first part of this functions tutorial
# ```

# %%
# `sum()` lambda function
sum = lambda x, y: x + y;

# Call the `sum()` anonymous function
print(sum(4,5))

# "Translate" to a UDF
def sum(x, y):
  return x+y
# Out:
# 9

# %% [markdown]
# # `Using main() as a Function`

# %% [markdown]
# ```
# If you have any experience with other programming languages such as Java,
# you’ll know that the main function is required to execute functions. As you have seen in the examples above,
# this is not necessarily needed for Python.
# However, including a main() function in your Python program can be handy to structure
# your code logically - all of the most important components are contained within this main() function.
#
# ```

# %%
# Define `main()` function
def main():
  hello()
  print("This is a main function")

main()
# Out:
# Hello World
# This is a main function

# %% [markdown]
# `the code of your main() function will be called when you import it as a module. To make sure that this doesn’t happen, you call the main() function when __name__ == '__main__'.`

# %%
# Define `main()` function
def main():
  hello()
  print("This is a main function")
  
# Execute `main()` function 
if __name__ == '__main__':
    main()

# %% [markdown]
# `Note that besides the __main__ function, you also have an __init__ function that initializes an instance of a class or an object. Simply stated, it acts as a constructor or initializer and is automatically called when you create a new instance of a class.`

# %%
class Dog:
    """    
    Requires:
    legs - Legs so that the dog can walk.
    color - A color of the fur.
    """

    def __init__(self, legs, color):
        self.legs = legs
        self.color = color
        
    def bark(self):
        bark = "bark" * 2
        return bark

if __name__ == "__main__":
    dog = Dog(4, "brown")
    bark = dog.bark()
    print(bark)

# %% [markdown]
# # **`PROBLEM SOLVING`**

# %% [markdown]
# Write a Python program to find the maximum from the given three numbers

# %%
def max_of_two( x, y ): 
    if x > y: 
      return x 
    else:
      return y

# %%
def max_of_three( x, y, z ): 
      return max_of_two( x, max_of_two( y, z ) )

# %%
print(max_of_three(3, 6, -5))
# Out:
# 6

# %%
print(max_of_three(3, 0, 0))
# Out:
# 3

# %% [markdown]
# Write a Python program to calculate the sum of all the numbers present in a list.

# %% [markdown]
#  Write a Python program to calculate the multiplication of all the numbers present in a list.

# %% [markdown]
# Write a Python program that takes a string as an input and calculates the number of upper case and lower case letters present in the string

# %% [markdown]
# Write a Python program that takes a number(non-negative integer) as an argument and calculates its factorial.

# %% [markdown]
# NEXT SESSION WE WILL BE LOOKING INTO RECURSION AND OBJECT ORIENTED PARADIGM OF PYTHON
